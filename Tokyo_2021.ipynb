# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("./Tokyo Medals 2021.csv")

# %% [markdown]
# ## Dataset İnfo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        93 non-null     object
#  1   Gold Medal     93 non-null     int64
#  2   Silver Medal   93 non-null     int64
#  3   Bronze Medal   93 non-null     int64
#  4   Total          93 non-null     int64
#  5   Rank By Total  93 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 4.5+ KB

# %% [markdown]
# ## Dataset Head & Tail

# %%
df.head()
# Out:
#                       Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank By Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
df.tail()
# Out:
#                  Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88                 Ghana           0             0             1      1
# 89               Grenada           0             0             1      1
# 90                Kuwait           0             0             1      1
# 91   Republic of Moldova           0             0             1      1
# 92  Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# 88             77
# 89             77
# 90             77
# 91             77
# 92             77

# %% [markdown]
# ## Medals Count of Countries

# %% [markdown]
# ### Cleaning Data

# %%
columns = df.columns
cleaning_columns = []
for i in columns:
    k = i.replace(" ","_")
    df.rename(columns = {i:k},inplace = True)

# %% [markdown]
# ### Gold Medals

# %%
gold = df[df["Gold_Medal"]>0]


plt.figure(figsize=(15,8))
plt.bar(gold["Country"],gold["Gold_Medal"])
plt.xticks(rotation = "vertical")
plt.xlabel("Country")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ### Silver Medals

# %%
silver = df[df["Silver_Medal"]>0]

plt.figure(figsize=(15,8))
plt.bar(silver["Country"],silver["Silver_Medal"])
plt.xticks(rotation = "vertical")
plt.xlabel("Country")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ### Bronze Medals

# %%
bronze = df[df["Bronze_Medal"]>0]

plt.figure(figsize=(15,8))
plt.bar(bronze["Country"],bronze["Bronze_Medal"])
plt.xticks(rotation = "vertical")
plt.xlabel("Country")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ### Total Medals

# %%
plt.figure(figsize=(20,10))
plt.bar(df["Country"],df["Total"])
plt.xticks(rotation = "vertical")
plt.xlabel("Country")
plt.ylabel("Value")
plt.show()

# %%
df.head()
# Out:
#                       Country  Gold_Medal  Silver_Medal  Bronze_Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank_By_Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3
