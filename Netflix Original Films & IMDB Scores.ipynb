# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### About this dataset
# Netflix Original Films & IMDB Scores as of 06/01/21

# %%
df = pd.read_csv("./NetflixOriginals.csv")

df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# ### Best IMDB Score

# %%
best_score = df.sort_values(by = "IMDB Score" , ascending=False)

#First 10 IMBD Score
best_score.head(10)
# Out:
#                                            Title  \
# 583     David Attenborough: A Life on Our Planet
# 582    Emicida: AmarElo - It's All For Yesterday
# 581                      Springsteen on Broadway
# 580  Winter on Fire: Ukraine's Fight for Freedom
# 579        Taylor Swift: Reputation Stadium Tour
# 578   Ben Platt: Live from Radio City Music Hall
# 577                       Dancing with the Birds
# 576                      Cuba and the Cameraman
# 573                                        Klaus
# 571                                         13th
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# 582                           Documentary   December 8, 2020       89
# 581                          One-man show  December 16, 2018      153
# 580                           Documentary    October 9, 2015       91
# 579                          Concert Film  December 31, 2018      125
# ...

# %% [markdown]
# ### Movie Genre

# %%
genre_unique_counts = df.groupby("Genre")["Genre"].value_counts()
genre_unique_name = df["Genre"].unique()


plt.figure(figsize=(18,9))
plt.bar(genre_unique_name,genre_unique_counts)
plt.ylabel("Genre Counts")
plt.xticks(rotation="vertical")
plt.xlabel("Genre Name")
plt.show()

# %%
#Genre Counts
df["Genre"].value_counts()
# Out:
# Documentary                           159
# Drama                                  77
# Comedy                                 49
# Romantic comedy                        39
# Thriller                               33
#                                      ...
# Musical / Short                         1
# Action/Science fiction                  1
# Action-adventure                        1
# Romantic thriller                       1
# Christmas/Fantasy/Adventure/Comedy      1
# Name: Genre, Length: 115, dtype: int64

# %% [markdown]
# ### Highest Runtime

# %%
high_runtime = df.sort_values(by = "Runtime" ,ascending=False )

#Top 10 Runtime
high_runtime.head(10)
# Out:
#                                Title                  Genre  \
# 561                     The Irishman            Crime drama
# 328                      Da 5 Bloods              War drama
# 581          Springsteen on Broadway           One-man show
# 247                         Citation                  Drama
# 284               The Forest of Love                  Drama
# 509                   Raat Akeli Hai               Thriller
# 7    The Last Days of American Crime    Heist film/Thriller
# 543                             Ludo  Anthology/Dark comedy
# 194                 Army of the Dead           Zombie/Heist
# 5                              Drive                 Action
#
#               Premiere  Runtime  IMDB Score  Language
# 561  November 27, 2019      209         7.8   English
# 328      June 12, 2020      155         6.5   English
# 581  December 16, 2018      153         8.5   English
# 247   November 6, 2020      151         6.2   English
# ...

# %% [markdown]
# ### Most Popular Movie Language

# %%
language = df["Language"].unique()
count_language = df.groupby("Language")["Language"].value_counts()

plt.figure(figsize=(20,8))
plt.bar(language,count_language)
plt.ylabel("Number")
plt.xticks(rotation="vertical")
plt.xlabel("Languages")
plt.show()

# %%
#Unique Language
language
# Out:
# array(['English/Japanese', 'Spanish', 'Italian', 'English', 'Hindi',
#        'Turkish', 'Korean', 'Indonesian', 'Malay', 'Dutch', 'French',
#        'English/Spanish', 'Portuguese', 'Filipino', 'German', 'Polish',
#        'Norwegian', 'Marathi', 'Thai', 'Swedish', 'Japanese',
#        'Spanish/Basque', 'Spanish/Catalan', 'English/Swedish',
#        'English/Taiwanese/Mandarin', 'Thia/English', 'English/Mandarin',
#        'Georgian', 'Bengali', 'Khmer/English/French', 'English/Hindi',
#        'Tamil', 'Spanish/English', 'English/Korean', 'English/Arabic',
#        'English/Russian', 'English/Akan', 'English/Ukranian/Russian'],
#       dtype=object)

# %%
#Unique Language Counts
df["Language"].value_counts()
# Out:
# English                       401
# Hindi                          33
# Spanish                        31
# French                         20
# Italian                        14
# Portuguese                     12
# Indonesian                      9
# Korean                          6
# Japanese                        6
# English/Spanish                 5
# German                          5
# Turkish                         5
# Polish                          3
# Dutch                           3
# Marathi                         3
# English/Hindi                   2
# English/Japanese                2
# English/Mandarin                2
# Thai                            2
# Filipino                        2
# Georgian                        1
# Swedish                         1
# Spanish/English                 1
# English/Taiwanese/Mandarin      1
# English/Akan                    1
# Bengali                         1
# Tamil                           1
# ...

# %% [markdown]
# # Top 3 Language Analysis

# %% [markdown]
# ## English

# %%
df_eng = df[df["Language"] == "English"]

df_eng
# Out:
#                                           Title                    Genre  \
# 3                                The Open House          Horror thriller
# 7               The Last Days of American Crime      Heist film/Thriller
# 8                                       Paradox  Musical/Western/Fantasy
# 10                         Searching for Sheela              Documentary
# 14                                        Mercy                 Thriller
# ..                                          ...                      ...
# 577                      Dancing with the Birds              Documentary
# 578  Ben Platt: Live from Radio City Music Hall             Concert Film
# 579       Taylor Swift: Reputation Stadium Tour             Concert Film
# 581                     Springsteen on Broadway             One-man show
# 583    David Attenborough: A Life on Our Planet              Documentary
#
#               Premiere  Runtime  IMDB Score Language
# ...

# %% [markdown]
# #### Best IMDB Score

# %%
best_english_score = df_eng.sort_values(by = "IMDB Score" , ascending=False)

#First 10 English IMDB Score
best_english_score.head(10)
# Out:
#                                           Title  \
# 583    David Attenborough: A Life on Our Planet
# 581                     Springsteen on Broadway
# 579       Taylor Swift: Reputation Stadium Tour
# 578  Ben Platt: Live from Radio City Music Hall
# 577                      Dancing with the Birds
# 576                     Cuba and the Cameraman
# 574                                  Seaspiracy
# 573                                       Klaus
# 572           Disclosure: Trans Lives on Screen
# 571                                        13th
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# 581                          One-man show  December 16, 2018      153
# 579                          Concert Film  December 31, 2018      125
# 578                          Concert Film       May 20, 2020       85
# 577                           Documentary   October 23, 2019       51
# ...

# %% [markdown]
# #### Genre Analysis

# %%
english_genre_count = df_eng.groupby("Genre")["Genre"].value_counts()
english_movie_name = df_eng["Genre"].unique()

plt.figure(figsize=(18,9))
plt.bar(english_movie_name,english_genre_count)
plt.ylabel("Genre Counts")
plt.xticks(rotation="vertical")
plt.xlabel("Genre Name")
plt.show()

# %% [markdown]
# ## Hindi

# %%
df_hin = df[df["Language"] == "Hindi"]

df_hin
# Out:
#                                      Title                  Genre  \
# 4                              Kaali Khuhi                Mystery
# 5                                    Drive                 Action
# 9                       Sardar Ka Grandson                 Comedy
# 16                           Ghost Stories       Horror anthology
# 23                   The Girl on the Train               Thriller
# 45                      Mrs. Serial Killer               Thriller
# 87          Gunjan Saxena: The Kargil Girl                  Drama
# 97   Dolly Kitty and Those Twinkling Stars                  Drama
# 100                                 Guilty               Thriller
# 112                           House Arrest                 Comedy
# 147                       Ginny Weds Sunny        Romantic comedy
# 168                Choked: Paisa Bolta Hai                  Drama
# 169                           Class of '83                  Drama
# ...

# %% [markdown]
# #### Best IMDB Score

# %%
best_score_hin = df_hin.sort_values(by = "IMDB Score" , ascending=False)

#First 10 Hindi IMDB Score
best_score_hin.head(10)
# Out:
#                     Title                  Genre           Premiere  Runtime  \
# 551            Yeh Ballet                  Drama  February 21, 2020      117
# 543                  Ludo  Anthology/Dark comedy  November 12, 2020      149
# 509        Raat Akeli Hai               Thriller      July 31, 2020      149
# 491                  Soni            Crime drama   January 18, 2019       97
# 486  Love per Square Foot        Romantic comedy  February 14, 2018      133
# 423              Pagglait           Comedy-drama     March 26, 2021      114
# 413              AK vs AK               Thriller  December 24, 2020      108
# 405           Serious Men                  Drama    October 2, 2020      114
# 397  Long Live Brij Mohan                 Comedy     August 3, 2018      105
# 388              Upstarts                  Drama   October 18, 2019      112
#
#      IMDB Score Language
# 551         7.6    Hindi
# 543         7.6    Hindi
# 509         7.3    Hindi
# ...

# %% [markdown]
# #### Genre Analysis

# %%
hindi_genre_count = df_hin.groupby("Genre")["Genre"].value_counts()
hindi_movie_name = df_hin["Genre"].unique()

plt.figure(figsize=(18,9))
plt.bar(hindi_movie_name,hindi_genre_count)
plt.ylabel("Genre Counts")
plt.xticks(rotation="vertical")
plt.xlabel("Genre Name")
plt.show()

# %% [markdown]
# ## Spanish

# %%
df_spa = df[df["Language"] == "Spanish"]

df_spa
# Out:
#                                              Title  \
# 1                                      Dark Forces
# 15                                  After the Raid
# 53                             The Day of the Lord
# 88                                       Intuition
# 92        Who Would You Take to a Deserted Island?
# 96                              Despite Everything
# 137                                  The Paramedic
# 144                                     Dad Wanted
# 190                                You've Got This
# 242                                Unknown Origins
# 246                                     Below Zero
# 254                          Offering to the Storm
# 276                               Notes for My Son
# 296                           Como Ca�do del Cielo
# 313                                   The Occupant
# 338                          Nobody Knows I'm Here
# 349                                Crazy About Her
# ...

# %% [markdown]
# #### Best IMDB Score

# %%
best_score_spa = df_spa.sort_values(by = "IMDB Score" , ascending=False)

best_score_spa
# Out:
#                                              Title  \
# 575          The Three Deaths of Marisela Escobedo
# 559                                           Roma
# 558                                   Road to Roma
# 504                             I'm No Longer Here
# 489                                      Seventeen
# 463            Guillermo Vilas: Settling the Score
# 458                        El Pepe: A Supreme Life
# 437          Los Tigres del Norte at Folsom Prison
# 436                     Lorena, Light-Footed Woman
# 392  A Life of Speed: The Juan Manuel Fangio Story
# 390                                         7 a�os
# 384                       Parchis: The Documentary
# 349                                Crazy About Her
# 361                           The Crimes That Bind
# 350                                Elisa & Marcela
# 338                          Nobody Knows I'm Here
# 313                                   The Occupant
# ...

# %% [markdown]
# #### Genre Analysis

# %%
spanish_genre_count = df_spa.groupby("Genre")["Genre"].value_counts()
spanish_movie_name = df_spa["Genre"].unique()

plt.figure(figsize=(18,9))
plt.bar(spanish_movie_name,spanish_genre_count)
plt.ylabel("Genre Counts")
plt.xticks(rotation="vertical")
plt.xlabel("Genre Name")
plt.show()

# %% [markdown]
# # Documentary Analysis

# %%
df_doc = df[df["Genre"] == "Documentary"]

df_doc
# Out:
#                                            Title        Genre  \
# 0                                Enter the Anime  Documentary
# 10                          Searching for Sheela  Documentary
# 15                                After the Raid  Documentary
# 20             Hello Privilege. It's Me, Chelsea  Documentary
# 30                                   After Maria  Documentary
# ..                                           ...          ...
# 576                      Cuba and the Cameraman   Documentary
# 577                       Dancing with the Birds  Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom  Documentary
# 582    Emicida: AmarElo - It's All For Yesterday  Documentary
# 583     David Attenborough: A Life on Our Planet  Documentary
#
#                Premiere  Runtime  IMDB Score                  Language
# 0        August 5, 2019       58         2.5          English/Japanese
# 10       April 22, 2021       58         4.1                   English
# ...

# %% [markdown]
# ## Best IMDB Score

# %%
best_score_doc = df_doc.sort_values(by = "IMDB Score" , ascending=False)

#First 10 Documentary IMDB Score
best_score_doc.head(10)
# Out:
#                                            Title        Genre  \
# 583     David Attenborough: A Life on Our Planet  Documentary
# 582    Emicida: AmarElo - It's All For Yesterday  Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom  Documentary
# 577                       Dancing with the Birds  Documentary
# 576                      Cuba and the Cameraman   Documentary
# 574                                   Seaspiracy  Documentary
# 571                                         13th  Documentary
# 572            Disclosure: Trans Lives on Screen  Documentary
# 575        The Three Deaths of Marisela Escobedo  Documentary
# 570                               Rising Phoenix  Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# 583    October 4, 2020       83         9.0                   English
# 582   December 8, 2020       89         8.6                Portuguese
# 580    October 9, 2015       91         8.4  English/Ukranian/Russian
# ...

# %% [markdown]
# ### Most Used Language in Documentary

# %%
doc_language = df_doc["Language"].unique()
doc_language_counts = df_doc.groupby("Language")["Language"].value_counts()

plt.figure(figsize=(20,8))
plt.bar(doc_language,doc_language_counts)
plt.ylabel("Number")
plt.xticks(rotation="vertical")
plt.xlabel("Languages")
plt.show()

# %% [markdown]
# # Drama Movies Analysis

# %%
df_dra = df[df["Genre"] == "Drama"]

df_dra
# Out:
#                           Title  Genre           Premiere  Runtime  \
# 11                     The Call  Drama  November 27, 2020      112
# 37                Finding Agnes  Drama  November 30, 2020      105
# 41                  The Binding  Drama    October 2, 2020       93
# 53          The Day of the Lord  Drama   October 30, 2020       93
# 56   Love Like the Falling Rain  Drama   October 15, 2020       86
# ..                          ...    ...                ...      ...
# 549               The Two Popes  Drama  December 20, 2019      125
# 551                  Yeh Ballet  Drama  February 21, 2020      117
# 559                        Roma  Drama  December 14, 2018      135
# 562  The Trial of the Chicago 7  Drama   October 16, 2020      130
# 565              Marriage Story  Drama   December 6, 2019      136
#
#      IMDB Score    Language
# 11          4.1      Korean
# 37          4.7    Filipino
# 41          4.7     Italian
# 53          4.9     Spanish
# ...

# %% [markdown]
# ## Best IMDB Score

# %%
best_score_dra = df_dra.sort_values(by = "IMDB Score" , ascending=False)

#First 10 Drama IMDB Score
best_score_dra.head(10)
# Out:
#                            Title  Genre            Premiere  Runtime  \
# 565               Marriage Story  Drama    December 6, 2019      136
# 562   The Trial of the Chicago 7  Drama    October 16, 2020      130
# 559                         Roma  Drama   December 14, 2018      135
# 551                   Yeh Ballet  Drama   February 21, 2020      117
# 549                The Two Popes  Drama   December 20, 2019      125
# 504           I'm No Longer Here  Drama        May 27, 2020      105
# 490                    Sometimes  Drama         May 1, 2018      101
# 488                 Private Life  Drama     October 5, 2018      124
# 481  First They Killed My Father  Drama  September 15, 2017      136
# 493                 The Disciple  Drama      April 30, 2021      129
#
#      IMDB Score              Language
# 565         7.9               English
# 562         7.8               English
# 559         7.7               Spanish
# 551         7.6                 Hindi
# ...

# %% [markdown]
# ## Most Used Language in Drama

# %%
dra_language = df_dra["Language"].unique()
dra_language_counts = df_dra.groupby("Language")["Language"].value_counts()

plt.figure(figsize=(20,8))
plt.bar(dra_language,dra_language_counts)
plt.ylabel("Number")
plt.xticks(rotation="vertical")
plt.xlabel("Languages")
plt.show()

# %% [markdown]
# # Comedy Movies Analysis

# %%
df_co = df[df["Genre"] == "Comedy"]

df_co
# Out:
#                                                 Title   Genre  \
# 6                                   Leyla Everlasting  Comedy
# 9                                  Sardar Ka Grandson  Comedy
# 18                          What Happened to Mr. Cha?  Comedy
# 22                                         Sextuplets  Comedy
# 27                                   Seriously Single  Comedy
# 28              The Misadventures of Hedi and Cokeman  Comedy
# 29                                   5 Star Christmas  Comedy
# 33   Porta dos Fundos: The First Temptation of Christ  Comedy
# 35                                        The Players  Comedy
# 47                                        Take the 10  Comedy
# 48                                     The Main Event  Comedy
# 54                                      Airplane Mode  Comedy
# 65                                       #REALITYHIGH  Comedy
# 69                                 Father of the Year  Comedy
# ...

# %% [markdown]
# ## Best IMDB Score

# %%
dra_best_score = df_co.sort_values(by = "IMDB Score" , ascending=False)

#First 10 Comedy Best IMDB Score
dra_best_score.head(10)
# Out:
#                                    Title   Genre           Premiere  Runtime  \
# 492              The 40-Year-Old Version  Comedy    October 9, 2020      124
# 447                          Rose Island  Comedy   December 9, 2020      117
# 399                        Death to 2020  Comedy  December 27, 2020       70
# 397                 Long Live Brij Mohan  Comedy     August 3, 2018      105
# 377               Just Another Christmas  Comedy   December 3, 2020      101
# 342         The Incredible Jessica James  Comedy      July 28, 2017       83
# 327                           Chopsticks  Comedy       May 31, 2019      100
# 278  Porta dos Fundos: The Last Hangover  Comedy  December 21, 2018       44
# 271                         Get the Goat  Comedy     March 18, 2021       97
# 261                           Win It All  Comedy      April 7, 2017       88
#
#      IMDB Score    Language
# 492         7.2     English
# 447         7.0     Italian
# 399         6.8     English
# ...

# %% [markdown]
# ## Most Used Language in Comedy

# %%
co_language = df_co["Language"].unique()
co_language_counts = df_dra.groupby("Language")["Language"].value_counts()

plt.figure(figsize=(20,8))
plt.bar(dra_language,dra_language_counts)
plt.ylabel("Number")
plt.xticks(rotation="vertical")
plt.xlabel("Languages")
plt.show()
